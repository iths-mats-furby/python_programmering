# %%
import pandas as pd
import sqlite3

"""class databashantering ():
    def create_database ():
        db = sqlite3.connect('vaccin_covid.db')
    def """

#vaccin_siffror = pd.read_csv('vaccin_covid.csv', sep=',', header=0)
vax = pd.read_csv('vaccin_covid.csv')
#weather = pd.read_csv('austin_weather.csv')
#weather.head()

#db = sqlite3.connect('austin_weather.db')
#weather.to_sql('weather', db)

# %%
vax.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        1.978400e+04       1.889900e+04             1.603900e+04
# mean         1.461085e+07       6.571691e+06             3.897520e+06
# std          8.261403e+07       2.384434e+07             1.367293e+07
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          1.503142e+05       1.235945e+05             5.653450e+04
# 50%          1.050294e+06       7.529080e+05             4.350570e+05
# 75%          5.252548e+06       3.451301e+06             2.065291e+06
# max          1.741812e+09       6.220000e+08             2.232990e+08
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            1.631200e+04        3.534500e+04
# mean             2.440215e+05        1.221596e+05
# std              1.314661e+06        8.740688e+05
# min              0.000000e+00        0.000000e+00
# 25%              4.662500e+03        8.520000e+02
# ...

# %%
vax.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35602 entries, 0 to 35601
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              35602 non-null  object
#  1   iso_code                             35602 non-null  object
#  2   date                                 35602 non-null  object
#  3   total_vaccinations                   19784 non-null  float64
#  4   people_vaccinated                    18899 non-null  float64
#  5   people_fully_vaccinated              16039 non-null  float64
#  6   daily_vaccinations_raw               16312 non-null  float64
#  7   daily_vaccinations                   35345 non-null  float64
#  8   total_vaccinations_per_hundred       19784 non-null  float64
#  9   people_vaccinated_per_hundred        18899 non-null  float64
#  10  people_fully_vaccinated_per_hundred  16039 non-null  float64
# ...

# %%
vax.head()
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
vax1 = vax.dropna()
len(vax1)
len(vax)

vax.pop(['country']), axis="columns")
#vax.isna()
# Out:
# 13642

# %% [markdown]
# ##### Ta bort kolumn

# %%
vax_new = vax.dropna(['country']), axis="columns")
#1 Ny data frame 
vax.drop(['country']), axis="columns", inplace=True)
#2 Vi skriver över vår dataframe
# Out:
#   File "C:\Users\hjalp\AppData\Local\Temp/ipykernel_20988/1274948689.py", line 1
#     vax_new = vax.dropna(['country']), axis="columns")
#               ^
# SyntaxError: cannot assign to function call

# %%
vax.head()

# %%
correlation =vax.corr()
print(vax)

# %%
import pandas as pd
import sqlite3

# Jenny Langs felaktiga kod

corona_vacc_df = pd.read_csv('vaccin_covid.csv')
db_connect = sqlite3.connect("corona_vacc.db")
cursor = db_connect.cursor()
corona_vacc_df.to_sql('corona_vacc', db_connect)
print(corona_vacc_df.head)
db_connect.commit()

# %% [markdown]
# # H1 This is a headline, lära mig Markdown
# ## H2 This is smaller
# ### H3 What is this
#
# **Bold**
# __Svart__
#
# _Kursiv text_
# *Italics*
